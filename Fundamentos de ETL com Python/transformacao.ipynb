# %%
##IMPORTAÇÃO DAS BIBLIOTECAS NECESSÁRIAS
import pandas as pd
import pandera as pa

# %%
##LIMPEZA JÁ NA EXTRAÇÃO
valores_ausentes = ['###!','####','****','*****', 'NULL']
##EXTRAÇÃO
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# ...

# %%
##VALIDAÇÃO
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia":pa.Column(pa.Int, required=False),
        "codigo_ocorrencia2":pa.Column(pa.Int),
        "ocorrencia_classificacao":pa.Column(pa.String),
        "ocorrencia_cidade":pa.Column(pa.String),
        "ocorrencia_uf":pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        "ocorrencia_aerodromo":pa.Column(pa.String, nullable=True),
        "ocorrencia_dia":pa.Column(pa.DateTime),
        "ocorrencia_hora":pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes":pa.Column(pa.Int)
    }
)

# %%
##VALIDAÇÃO
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
##verificar os tipos dos campos
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
##buscar os dados pelo index
df.iloc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
##outra forma de buscar e retornar apenas uma coluna
df['ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 6109    PE
# 6110    RO
# 6111    PA
# 6112    MT
# 6113    SP
# Name: ocorrencia_uf, Length: 6114, dtype: object

# %%
## buscar todos os valores que são nulos
filtro = df.ocorrencia_uf.isnull()
df.loc[filtro]
# Out:
# Empty DataFrame
# Columns: [codigo_ocorrencia, codigo_ocorrencia2, ocorrencia_classificacao, ocorrencia_cidade, ocorrencia_uf, ocorrencia_aerodromo, ocorrencia_dia, ocorrencia_hora, total_recomendacoes]
# Index: []

# %%
## buscar todos os valores que são nulos
filtro = df.ocorrencia_aerodromo.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6092              80236               80236                 ACIDENTE
# 6093              80227               80227                 ACIDENTE
# 6096              80229               80229                INCIDENTE
# 6099              80233               80233                 ACIDENTE
# 6112              80257               80257                 ACIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
## buscar todos os valores que são nulos
filtro = df.ocorrencia_hora.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 4102              78823               78823                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 4102           CORUMBÁ            MS                  NaN     2017-07-09
#
#      ocorrencia_hora  total_recomendacoes
# 4102             NaN                    0

# %%
##contar valores :: não conta valores não informados (nulos) 
df.count()
# Out:
# codigo_ocorrencia           6114
# codigo_ocorrencia2          6114
# ocorrencia_classificacao    6114
# ocorrencia_cidade           6114
# ocorrencia_uf               6114
# ocorrencia_aerodromo        3658
# ocorrencia_dia              6114
# ocorrencia_hora             6113
# total_recomendacoes         6114
# dtype: int64

# %%
##ocorrencias com mais de 10 recomendações
filtro = df.total_recomendacoes > 10
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 63                39992               39992                 ACIDENTE
# 326               42250               42250                 ACIDENTE
# 530               43471               43471                 ACIDENTE
# 727               44377               44377                 ACIDENTE
# 872               44796               44796                 ACIDENTE
# 884               44888               44888          INCIDENTE GRAVE
# 1062              45554               45554          INCIDENTE GRAVE
# 1972              47938               47938                INCIDENTE
# 2797              52265               52265                 ACIDENTE
# 3932              66432               66432          INCIDENTE GRAVE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 63               SÃO PAULO            SP                 SBMT     2010-02-17
# ...

# %%
##ocorrencias com mais de 10 recomendações, especificando as colunas que quero retornar
filtro = df.total_recomendacoes > 10
df.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               SÃO PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              SÃO PAULO                   11
# 727               ITÁPOLIS                   11
# 872                 RECIFE                   23
# 884   SÃO JOSÉ DOS PINHAIS                   11
# 1062            UBERLÂNDIA                   20
# 1972              BRASÍLIA                   11
# 2797                SANTOS                   13
# 3932               VITÓRIA                   12

# %%
##ocorrencias cuja classificação == INCIDENTE GRAVE
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes', 'ocorrencia_classificacao']]
# Out:
#      ocorrencia_cidade  total_recomendacoes ocorrencia_classificacao
# 7             CANUTAMA                    3          INCIDENTE GRAVE
# 8             CASCAVEL                    2          INCIDENTE GRAVE
# 9        PARÁ DE MINAS                    0          INCIDENTE GRAVE
# 29            CURITIBA                    2          INCIDENTE GRAVE
# 35              PALMAS                    0          INCIDENTE GRAVE
# ...                ...                  ...                      ...
# 6090             MARAÚ                    0          INCIDENTE GRAVE
# 6095   ELDORADO DO SUL                    0          INCIDENTE GRAVE
# 6097     CAXIAS DO SUL                    0          INCIDENTE GRAVE
# 6098   CHAPADÃO DO SUL                    0          INCIDENTE GRAVE
# 6104       VOTUPORANGA                    0          INCIDENTE GRAVE
#
# [791 rows x 3 columns]

# %%
##ocorrencias cuja classificação == INCIDENTE GRAVE e o estado == SP
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 136               40270               40270          INCIDENTE GRAVE
# 171               40620               40620          INCIDENTE GRAVE
# 219               41411               41411          INCIDENTE GRAVE
# 297               42289               42289          INCIDENTE GRAVE
# 314               42323               42323          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5949              80056               80056          INCIDENTE GRAVE
# 6000              80114               80114          INCIDENTE GRAVE
# 6007              80124               80124          INCIDENTE GRAVE
# 6081              80200               80200          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
##ocorrencias cuja classificação == INCIDENTE GRAVE ou o estado == SP
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# ...                 ...                 ...                      ...
# 6097              80231               80231          INCIDENTE GRAVE
# 6098              80248               80248          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
##ocorrencias cuja (classificação == INCIDENTE GRAVE ou classificação == INCIDENTE) e o estado == SP
filtro1 = (df.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (df.ocorrencia_classificacao == 'INCIDENTE')
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 4                 40324               40324                INCIDENTE
# 5                 39807               39807                INCIDENTE
# ...                 ...                 ...                      ...
# 6108              80244               80244                INCIDENTE
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
##ocorrencias cuja (classificação == INCIDENTE GRAVE ou classificação == INCIDENTE) e o estado == SP
filtro1 = df.ocorrencia_classificacao.isin(['INCIDENTE GRAVE', 'INCIDENTE'])
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 4                 40324               40324                INCIDENTE
# 5                 39807               39807                INCIDENTE
# ...                 ...                 ...                      ...
# 6108              80244               80244                INCIDENTE
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
##buscar todas as ocorrencias cuja a cidade comecem com a letra "C"
filtro = df.ocorrencia_cidade.str[0] == 'C'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 40215               40215                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 20                40310               40310                INCIDENTE
# ...                 ...                 ...                      ...
# 6094              80225               80225                INCIDENTE
# 6097              80231               80231          INCIDENTE GRAVE
# 6098              80248               80248          INCIDENTE GRAVE
# 6100              80235               80235                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
##buscar todas as ocorrencias cuja a cidade terminam com a letra "A"
filtro = df.ocorrencia_cidade.str[-1] == 'A'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 12                40414               40414                INCIDENTE
# 15                39315               39315                 ACIDENTE
# 25                39772               39772                INCIDENTE
# 26                39847               39847                INCIDENTE
# ...                 ...                 ...                      ...
# 6093              80227               80227                 ACIDENTE
# 6094              80225               80225                INCIDENTE
# 6102              80240               80240                INCIDENTE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
##buscar todas as ocorrencias cuja a cidade terminam com os caracteres "MA"
filtro = df.ocorrencia_cidade.str[-2:] == 'MA'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 408               43062               43062                 ACIDENTE
# 688               44198               44198                 ACIDENTE
# 1035              51785               51785                INCIDENTE
# 1377              45939               45939                 ACIDENTE
# 1401              46180               46180                 ACIDENTE
# 2099              49113               49113          INCIDENTE GRAVE
# 2102              48799               48799                 ACIDENTE
# 2646              80059               80059                INCIDENTE
# 2657              51347               51347                INCIDENTE
# 2857              52340               52340                 ACIDENTE
# 2968              52832               52832                 ACIDENTE
# ...

# %%
##buscar todas as ocorrencias cuja a cidade contem (em qualquer parte do conteúdo) com os caracteres "MA"
filtro = df.ocorrencia_cidade.str.contains('MA')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507                 ACIDENTE
# 15                39315               39315                 ACIDENTE
# 35                39487               39487          INCIDENTE GRAVE
# 78                39916               39916          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6075              80205               80205                INCIDENTE
# 6086              80212               80212                INCIDENTE
# 6090              80221               80221          INCIDENTE GRAVE
# 6093              80227               80227                 ACIDENTE
# 6106              80249               80249                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
##buscar todas as ocorrencias cuja a cidade contem com os caracteres "MA" ou "AL"
filtro = df.ocorrencia_cidade.str.contains('MA|AL')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507                 ACIDENTE
# 15                39315               39315                 ACIDENTE
# 17                39810               39810                INCIDENTE
# ...                 ...                 ...                      ...
# 6075              80205               80205                INCIDENTE
# 6086              80212               80212                INCIDENTE
# 6090              80221               80221          INCIDENTE GRAVE
# 6093              80227               80227                 ACIDENTE
# 6106              80249               80249                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
##Ocorrencias do ano de 2015
filtro = df.ocorrencia_dia.dt.year == 2015
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2998              52992               52992          INCIDENTE GRAVE
# 2999              52979               52979                 ACIDENTE
# 3000              53073               53073                INCIDENTE
# 3001              53074               53074                INCIDENTE
# 3002              52976               52976                 ACIDENTE
# ...                 ...                 ...                      ...
# 3464              60632               60632          INCIDENTE GRAVE
# 3465              60600               60600                INCIDENTE
# 3466              60642               60642                INCIDENTE
# 3467              60631               60631                 ACIDENTE
# 3468              60649               60649                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
##Ocorrencias do ano de 2015 e mês 12
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 12
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3430              53573               53573                INCIDENTE
# 3431              60601               60601                INCIDENTE
# 3432              53634               53634                INCIDENTE
# 3433              53636               53636                INCIDENTE
# 3434              53575               53575                INCIDENTE
# 3435              60637               60637                INCIDENTE
# 3436              53625               53625                 ACIDENTE
# 3437              53626               53626                 ACIDENTE
# 3438              53628               53628                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631                INCIDENTE
# 3441              60636               60636                INCIDENTE
# 3442              53627               53627                INCIDENTE
# ...

# %%
##Ocorrencias do ano de 2015 e mês 12 e dia 08
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 12
filtro3 = df.ocorrencia_dia.dt.day == 8
df.loc[filtro1 & filtro2 & filtro3]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3438              53628               53628                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631                INCIDENTE
# 3441              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3438             AGUAÍ            SP                  NaN     2015-12-08
# 3439             JALES            SP                 SDJL     2015-12-08
# 3440          CAMPINAS            SP                 SBKP     2015-12-08
# 3441     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 3438        14:30:00                    1
# 3439        10:20:00                    0
# 3440        16:19:00                    0
# 3441        13:00:00                    0

# %%
##concatenar duas colunas e converter para datetime
df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 0        12:00:00                    0 2010-01-03 12:00:00
# ...

# %%
##
filtro1 = df.ocorrencia_dia_hora >= '2015-12-03 11:00:00'
filtro2 = df.ocorrencia_dia_hora <= '2015-12-08 13:00:00'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3435              60637               60637                INCIDENTE
# 3436              53625               53625                 ACIDENTE
# 3437              53626               53626                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3441              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3435    BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3436          TRINDADE            GO                  NaN     2015-12-06
# 3437         AMERICANA            SP                 SDAI     2015-12-06
# 3439             JALES            SP                 SDJL     2015-12-08
# 3441     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# ...

# %%
##Ocorrencias do ano de 2015 e mês 03
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 3
df201503 = df.loc[filtro1 & filtro2]

# %%
df201503.count()
# Out:
# codigo_ocorrencia           37
# codigo_ocorrencia2          37
# ocorrencia_classificacao    37
# ocorrencia_cidade           37
# ocorrencia_uf               37
# ocorrencia_aerodromo        21
# ocorrencia_dia              37
# ocorrencia_hora             37
# total_recomendacoes         37
# ocorrencia_dia_hora         37
# dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).codigo_ocorrencia.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# Name: codigo_ocorrencia, dtype: int64

# %%
##contar o numero de linhas que foram agrupadas
df201503.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# dtype: int64

# %%
##contar o numero de linhas que foram agrupadas e ordenar por ASC
df201503.groupby(['ocorrencia_classificacao']).size().sort_values()
# Out:
# ocorrencia_classificacao
# INCIDENTE GRAVE     5
# ACIDENTE           15
# INCIDENTE          17
# dtype: int64

# %%
##contar o numero de linhas que foram agrupadas e ordenar por DESC
df201503.groupby(['ocorrencia_classificacao']).size().sort_values(ascending=False)
# Out:
# ocorrencia_classificacao
# INCIDENTE          17
# ACIDENTE           15
# INCIDENTE GRAVE     5
# dtype: int64

# %%
filtro1 = df.ocorrencia_uf.isin(['ES','SP','RJ','MG'])
filtro2 = df.ocorrencia_dia.dt.year == 2010
dfsudeste2010 = df.loc[filtro1 & filtro2]

# %%
dfsudeste2010.groupby(['ocorrencia_classificacao', 'ocorrencia_uf']).size()
# Out:
# ocorrencia_classificacao  ocorrencia_uf
# ACIDENTE                  MG                7
#                           RJ                9
#                           SP               24
# INCIDENTE                 ES                5
#                           MG               39
#                           RJ               52
#                           SP               74
# INCIDENTE GRAVE           MG                5
#                           RJ                4
#                           SP                9
# dtype: int64

# %%
filtro = dfsudeste2010.ocorrencia_cidade == 'RIO DE JANEIRO'
dfsudeste2010.loc[filtro].total_recomendacoes.sum()
# Out:
# 25

# %%
##trabalhar apenas com os registros que tem recomendacoes
filtro = dfsudeste2010.total_recomendacoes > 0
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values()
# Out:
# ocorrencia_cidade
# BOITUVA                   1
# BOM JESUS DO GALHO        1
# ITANHAÉM                  1
# BELO HORIZONTE            2
# SÃO BERNARDO DO CAMPO     2
# IPERÓ                     3
# NOVO HORIZONTE            3
# TIMÓTEO                   3
# JUNDIAÍ                   7
# RESENDE                   8
# BRAGANÇA PAULISTA         9
# CAMANDUCAIA               9
# RIO DE JANEIRO           25
# SÃO PAULO                41
# Name: total_recomendacoes, dtype: int64
